# %%
from abc import ABC, abstractmethod
class Resume(ABC):
 
    def move(self):
        pass
 
class Java Developer(Resume):
 
    def move(self):
class Testing(Resume):
 
    def move(self):
        
class DevOps Engineer(Resume):
 
    def move(self):
class Python Developer(Resume):
 
    def move(self):
class Web Designing(Resume):
 
    def move(self):
class HR(Resume):
 
    def move(self):
class Hadoop(Resume):
 
    def move(self):
class Blockchain(Resume):
 
    def move(self):
class ETL Developer(Resume):
 
    def move(self):
class Operations Manager(Resume):
 
    def move(self):
class Data Science(Resume):
 
    def move(self):
class Sales(Resume):
 
    def move(self):
class Mechanical Engineer(Resume):
 
    def move(self):
class Arts(Resume):
 
    def move(self):
class Database(Resume):
 
    def move(self):
class Electrical Engineering(Resume):
 
    def move(self):
class Health nd fitness(Resume):
 
    def move(self):
class PMO(Resume):
 
    def move(self):
class Business Analyst(Resume):
 
    def move(self):
class DotNet Developer(Resume):
 
    def move(self):
class Automation Testing(Resume):
 
    def move(self):
class Network Security Engineer(Resume):
 
    def move(self):
class SAP Developer(Resume):
 
    def move(self):
class Civil Engineer(Resume):
 
    def move(self):
class Advocate(Resume):
 
    def move(self):

# Driver code

R = Java Developer()
R.move()
 
K = Testing()
K.move()

R = DevOps Engineer()
R.move()
 
K = Python Developer()
K.move()

R = Web Designing()
R.move()
 
K = HR()
K.move()

R = Hadoop()
R.move()
 
K = Blockchain()
K.move()

R = ETL Developer()
R.move()
 
K = Operations Manager()
K.move()

R = Data Science()
R.move()
 
K = Sales()
K.move()

R = Mechanical Engineer()
R.move()
 
K = Arts()
K.move()

R = Database()
R.move()
 
K = Electrical Engineering()
K.move()

R = Health nd fitness()
R.move()
 
K = PMO()
K.move()

R = Business Analyst()
R.move()
 
K = DotNet Developer()
K.move()

R = Automation Testing()
R.move()
 
K = Network Security Engineer()
K.move()

R = SAP Developer()
R.move()
 
K = Civil Engineer()
K.move()

R = Advocate()
R.move()
